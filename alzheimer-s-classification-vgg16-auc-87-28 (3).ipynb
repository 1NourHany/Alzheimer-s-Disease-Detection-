# %% [markdown]
# ### IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import skimage.io
import os 
import tqdm
import glob
import tensorflow 

from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import grey2rgb

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.utils import to_categorical
import keras.backend as K
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %% [markdown]
# ### IMPORTING / VIEWING / PREPROCESSING DATASET

# %% [markdown]
# > `DATA AUGMENTATION`

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   rotation_range=30,
                                   zoom_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   validation_split = 0.2)

valid_datagen = ImageDataGenerator(rescale = 1./255,
                                   validation_split = 0.2)

test_datagen  = ImageDataGenerator(rescale = 1./255)

# %%
test_dataset = test_datagen.flow_from_directory(directory = '../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/test',
                                                  target_size = (224,224),
                                                  class_mode = 'categorical',
                                                  batch_size = 32)
# Out:
# Found 1279 images belonging to 4 classes.

# %%
train_dataset  = train_datagen.flow_from_directory(directory = '../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/train',
                                                   target_size = (224,224),
                                                   class_mode = 'categorical',
                                                   subset = 'training',
                                                   batch_size = 128)
# Out:
# Found 4098 images belonging to 4 classes.

# %%
valid_dataset = valid_datagen.flow_from_directory(directory = '../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/train',
                                                  target_size = (224,224),
                                                  class_mode = 'categorical',
                                                  subset = 'validation',
                                                  batch_size = 128)
# Out:
# Found 1023 images belonging to 4 classes.

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 5, figsize=(20,20))

for i in tqdm(range(0,5)):
    rand1 = np.random.randint(len(train_dataset))
    rand2 = np.random.randint(100)
    ax[i].imshow(train_dataset[rand1][0][rand2])
    ax[i].axis('off')
    a = train_dataset[rand1][1][rand2]
    if a[0] == 1:
        ax[i].set_title('Mild Dementia')
    elif a[1] == 1:
        ax[i].set_title('Moderate Dementia')
    elif a[2] == 1:
        ax[i].set_title('Non Demetia')
    elif a[3] == 1:
        ax[i].set_title('Very Mild Dementia')
# Out:
# 100%|██████████| 5/5 [00:12<00:00,  2.51s/it]

# %% [markdown]
# ### MODEL BUILDING

# %%
base_model = VGG16(input_shape=(224,224,3), 
                   include_top=False,
                   weights="imagenet")

# %%
# Freezing Layers

for layer in base_model.layers:
    layer.trainable=False

# %%
# Building Model

model=Sequential()
model.add(base_model)
model.add(Dropout(0.5))
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(2048,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1024,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(4,activation='softmax'))

# %%
# Model Summary

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 25088)             100352
# _________________________________________________________________
# dense_3 (Dense)              (None, 2048)              51382272
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 2048)              8192
# _________________________________________________________________
# activation_2 (Activation)    (None, 2048)              0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 1024)              4096
# _________________________________________________________________
# activation_3 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 68,311,876
# Trainable params: 53,540,868
# Non-trainable params: 14,771,008
# _________________________________________________________________

# %%
def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
# Model Compile 

OPT    = tensorflow.keras.optimizers.Adam(lr=0.001)
METRICS = [
      tensorflow.keras.metrics.AUC(name = 'auc'),
      tensorflow.keras.metrics.BinaryAccuracy(name='accuracy'),
      tensorflow.keras.metrics.Precision(name='precision'),
      tensorflow.keras.metrics.Recall(name='recall'),  
        f1_score,
          ]
model.compile(loss='categorical_crossentropy',
              metrics=METRICS,
              optimizer=OPT)

# %%
# Defining Callbacks

filepath = './best_weights.hdf5'

earlystopping = EarlyStopping(monitor = 'val_auc', 
                              mode = 'max' , 
                              patience = 15,
                              verbose = 1)

checkpoint    = ModelCheckpoint(filepath, 
                                monitor = 'val_auc', 
                                mode='max', 
                                save_best_only=True, 
                                verbose = 1)


callback_list = [earlystopping, checkpoint]

# %%
model_history=model.fit(train_dataset,
                        validation_data=valid_dataset,
                        epochs = 20,
                        callbacks = callback_list,
                        verbose = 1)
# Out:
# Epoch 1/20
# 33/33 [==============================] - ETA: 0s - loss: 1.3548 - auc: 0.7823 - accuracy: 0.7647 - precision: 0.5333 - recall: 0.4705 - f1_score: 0.4998
# Epoch 00001: val_auc improved from -inf to 0.77280, saving model to ./best_weights.hdf5
# 33/33 [==============================] - 53s 2s/step - loss: 1.3548 - auc: 0.7823 - accuracy: 0.7647 - precision: 0.5333 - recall: 0.4705 - f1_score: 0.4998 - val_loss: 1.1986 - val_auc: 0.7728 - val_accuracy: 0.7483 - val_precision: 0.4957 - val_recall: 0.3939 - val_f1_score: 0.4380
# Epoch 2/20
# 33/33 [==============================] - ETA: 0s - loss: 1.1968 - auc: 0.8073 - accuracy: 0.7712 - precision: 0.5480 - recall: 0.4846 - f1_score: 0.5138
# Epoch 00002: val_auc did not improve from 0.77280
# 33/33 [==============================] - 50s 2s/step - loss: 1.1968 - auc: 0.8073 - accuracy: 0.7712 - precision: 0.5480 - recall: 0.4846 - f1_score: 0.5138 - val_loss: 1.1621 - val_auc: 0.7460 - val_accuracy: 0.7534 - val_precision: 0.5141 - val_recall: 0.2502 - val_f1_score: 0.3360
# Epoch 3/20
# 32/33 [============================>.] - ETA: 1s - loss: 1.0565 - auc: 0.8297 - accuracy: 0.7891 - precision: 0.5913 - recall: 0.5068 - f1_score: 0.5456
# Epoch 00003: val_auc improved from 0.77280 to 0.77670, saving model to ./best_weights.hdf5
# 33/33 [==============================] - 52s 2s/step - loss: 1.0563 - auc: 0.8297 - accuracy: 0.7892 - precision: 0.5915 - recall: 0.5071 - f1_score: 0.5594 - val_loss: 1.1094 - val_auc: 0.7767 - val_accuracy: 0.7774 - val_precision: 0.5895 - val_recall: 0.3607 - val_f1_score: 0.4470
# Epoch 4/20
# 33/33 [==============================] - ETA: 0s - loss: 0.9919 - auc: 0.8438 - accuracy: 0.7967 - precision: 0.6083 - recall: 0.5249 - f1_score: 0.5614
# Epoch 00004: val_auc did not improve from 0.77670
# 33/33 [==============================] - 50s 2s/step - loss: 0.9919 - auc: 0.8438 - accuracy: 0.7967 - precision: 0.6083 - recall: 0.5249 - f1_score: 0.5614 - val_loss: 1.1142 - val_auc: 0.7728 - val_accuracy: 0.7862 - val_precision: 0.6194 - val_recall: 0.3754 - val_f1_score: 0.4674
# Epoch 5/20
# 33/33 [==============================] - ETA: 0s - loss: 0.9446 - auc: 0.8516 - accuracy: 0.7989 - precision: 0.6132 - recall: 0.5293 - f1_score: 0.5660
# Epoch 00005: val_auc improved from 0.77670 to 0.79964, saving model to ./best_weights.hdf5
# 33/33 [==============================] - 52s 2s/step - loss: 0.9446 - auc: 0.8516 - accuracy: 0.7989 - precision: 0.6132 - recall: 0.5293 - f1_score: 0.5660 - val_loss: 1.0163 - val_auc: 0.7996 - val_accuracy: 0.7686 - val_precision: 0.5579 - val_recall: 0.3578 - val_f1_score: 0.4358
# Epoch 6/20
# 33/33 [==============================] - ETA: 0s - loss: 0.9118 - auc: 0.8595 - accuracy: 0.8086 - precision: 0.6371 - recall: 0.5449 - f1_score: 0.5848
# Epoch 00006: val_auc did not improve from 0.79964
# 33/33 [==============================] - 50s 2s/step - loss: 0.9118 - auc: 0.8595 - accuracy: 0.8086 - precision: 0.6371 - recall: 0.5449 - f1_score: 0.5848 - val_loss: 1.0357 - val_auc: 0.7886 - val_accuracy: 0.7644 - val_precision: 0.5463 - val_recall: 0.3402 - val_f1_score: 0.4190
# Epoch 7/20
# 33/33 [==============================] - ETA: 0s - loss: 0.8711 - auc: 0.8696 - accuracy: 0.8156 - precision: 0.6523 - recall: 0.5617 - f1_score: 0.6004
# Epoch 00007: val_auc did not improve from 0.79964
# 33/33 [==============================] - 49s 1s/step - loss: 0.8711 - auc: 0.8696 - accuracy: 0.8156 - precision: 0.6523 - recall: 0.5617 - f1_score: 0.6004 - val_loss: 1.0514 - val_auc: 0.7859 - val_accuracy: 0.7717 - val_precision: 0.5675 - val_recall: 0.3656 - val_f1_score: 0.4439
# Epoch 8/20
# 33/33 [==============================] - ETA: 0s - loss: 0.8692 - auc: 0.8694 - accuracy: 0.8173 - precision: 0.6579 - recall: 0.5612 - f1_score: 0.6025
# Epoch 00008: val_auc improved from 0.79964 to 0.80818, saving model to ./best_weights.hdf5
# 33/33 [==============================] - 52s 2s/step - loss: 0.8692 - auc: 0.8694 - accuracy: 0.8173 - precision: 0.6579 - recall: 0.5612 - f1_score: 0.6025 - val_loss: 1.0298 - val_auc: 0.8082 - val_accuracy: 0.7742 - val_precision: 0.5666 - val_recall: 0.4115 - val_f1_score: 0.4759
# Epoch 9/20
# 33/33 [==============================] - ETA: 0s - loss: 0.8452 - auc: 0.8740 - accuracy: 0.8160 - precision: 0.6536 - recall: 0.5617 - f1_score: 0.6008
# Epoch 00009: val_auc improved from 0.80818 to 0.82064, saving model to ./best_weights.hdf5
# 33/33 [==============================] - 52s 2s/step - loss: 0.8452 - auc: 0.8740 - accuracy: 0.8160 - precision: 0.6536 - recall: 0.5617 - f1_score: 0.6008 - val_loss: 1.0227 - val_auc: 0.8206 - val_accuracy: 0.7742 - val_precision: 0.5634 - val_recall: 0.4301 - val_f1_score: 0.4875
# Epoch 10/20
# 33/33 [==============================] - ETA: 0s - loss: 0.8324 - auc: 0.8776 - accuracy: 0.8200 - precision: 0.6651 - recall: 0.5637 - f1_score: 0.6069
# Epoch 00010: val_auc did not improve from 0.82064
# 33/33 [==============================] - 49s 1s/step - loss: 0.8324 - auc: 0.8776 - accuracy: 0.8200 - precision: 0.6651 - recall: 0.5637 - f1_score: 0.6069 - val_loss: 1.0675 - val_auc: 0.7976 - val_accuracy: 0.7537 - val_precision: 0.5094 - val_recall: 0.3969 - val_f1_score: 0.4462
# Epoch 11/20
# 33/33 [==============================] - ETA: 0s - loss: 0.8226 - auc: 0.8793 - accuracy: 0.8194 - precision: 0.6635 - recall: 0.5634 - f1_score: 0.6058
# Epoch 00011: val_auc did not improve from 0.82064
# 33/33 [==============================] - 50s 2s/step - loss: 0.8226 - auc: 0.8793 - accuracy: 0.8194 - precision: 0.6635 - recall: 0.5634 - f1_score: 0.6058 - val_loss: 1.0549 - val_auc: 0.8090 - val_accuracy: 0.7647 - val_precision: 0.5363 - val_recall: 0.4330 - val_f1_score: 0.4787
# Epoch 12/20
# 33/33 [==============================] - ETA: 0s - loss: 0.7827 - auc: 0.8896 - accuracy: 0.8335 - precision: 0.6937 - recall: 0.5981 - f1_score: 0.6379
# Epoch 00012: val_auc did not improve from 0.82064
# 33/33 [==============================] - 49s 1s/step - loss: 0.7827 - auc: 0.8896 - accuracy: 0.8335 - precision: 0.6937 - recall: 0.5981 - f1_score: 0.6379 - val_loss: 0.9858 - val_auc: 0.8192 - val_accuracy: 0.7737 - val_precision: 0.5616 - val_recall: 0.4321 - val_f1_score: 0.4874
# Epoch 13/20
# 33/33 [==============================] - ETA: 0s - loss: 0.8026 - auc: 0.8847 - accuracy: 0.8256 - precision: 0.6740 - recall: 0.5861 - f1_score: 0.6230
# Epoch 00013: val_auc improved from 0.82064 to 0.83303, saving model to ./best_weights.hdf5
# 33/33 [==============================] - 51s 2s/step - loss: 0.8026 - auc: 0.8847 - accuracy: 0.8256 - precision: 0.6740 - recall: 0.5861 - f1_score: 0.6230 - val_loss: 1.0114 - val_auc: 0.8330 - val_accuracy: 0.7737 - val_precision: 0.5573 - val_recall: 0.4614 - val_f1_score: 0.5044
# Epoch 14/20
# 33/33 [==============================] - ETA: 0s - loss: 0.7525 - auc: 0.8979 - accuracy: 0.8366 - precision: 0.6998 - recall: 0.6064 - f1_score: 0.6452
# Epoch 00014: val_auc did not improve from 0.83303
# 33/33 [==============================] - 50s 2s/step - loss: 0.7525 - auc: 0.8979 - accuracy: 0.8366 - precision: 0.6998 - recall: 0.6064 - f1_score: 0.6452 - val_loss: 1.0335 - val_auc: 0.8166 - val_accuracy: 0.7715 - val_precision: 0.5542 - val_recall: 0.4399 - val_f1_score: 0.4903
# Epoch 15/20
# 33/33 [==============================] - ETA: 0s - loss: 0.7791 - auc: 0.8899 - accuracy: 0.8302 - precision: 0.6854 - recall: 0.5932 - f1_score: 0.6168
# Epoch 00015: val_auc improved from 0.83303 to 0.84072, saving model to ./best_weights.hdf5
# 33/33 [==============================] - 52s 2s/step - loss: 0.7791 - auc: 0.8899 - accuracy: 0.8302 - precision: 0.6854 - recall: 0.5932 - f1_score: 0.6168 - val_loss: 0.9211 - val_auc: 0.8407 - val_accuracy: 0.7840 - val_precision: 0.5857 - val_recall: 0.4643 - val_f1_score: 0.5179
# Epoch 16/20
# 33/33 [==============================] - ETA: 0s - loss: 0.7575 - auc: 0.8958 - accuracy: 0.8343 - precision: 0.6966 - recall: 0.5974 - f1_score: 0.6388
# Epoch 00016: val_auc did not improve from 0.84072
# 33/33 [==============================] - 50s 2s/step - loss: 0.7575 - auc: 0.8958 - accuracy: 0.8343 - precision: 0.6966 - recall: 0.5974 - f1_score: 0.6388 - val_loss: 0.9939 - val_auc: 0.8336 - val_accuracy: 0.7781 - val_precision: 0.5662 - val_recall: 0.4809 - val_f1_score: 0.5198
# Epoch 17/20
# 33/33 [==============================] - ETA: 0s - loss: 0.7242 - auc: 0.9046 - accuracy: 0.8441 - precision: 0.7157 - recall: 0.6247 - f1_score: 0.6767
# Epoch 00017: val_auc did not improve from 0.84072
# 33/33 [==============================] - 50s 2s/step - loss: 0.7242 - auc: 0.9046 - accuracy: 0.8441 - precision: 0.7157 - recall: 0.6247 - f1_score: 0.6767 - val_loss: 0.9775 - val_auc: 0.8356 - val_accuracy: 0.7742 - val_precision: 0.5561 - val_recall: 0.4800 - val_f1_score: 0.5148
# Epoch 18/20
# 33/33 [==============================] - ETA: 0s - loss: 0.7240 - auc: 0.9036 - accuracy: 0.8415 - precision: 0.7102 - recall: 0.6184 - f1_score: 0.6709
# Epoch 00018: val_auc did not improve from 0.84072
# 33/33 [==============================] - 49s 1s/step - loss: 0.7240 - auc: 0.9036 - accuracy: 0.8415 - precision: 0.7102 - recall: 0.6184 - f1_score: 0.6709 - val_loss: 1.0042 - val_auc: 0.8245 - val_accuracy: 0.7666 - val_precision: 0.5385 - val_recall: 0.4643 - val_f1_score: 0.4985
# Epoch 19/20
# 33/33 [==============================] - ETA: 0s - loss: 0.7310 - auc: 0.9030 - accuracy: 0.8413 - precision: 0.7109 - recall: 0.6157 - f1_score: 0.6548
# Epoch 00019: val_auc did not improve from 0.84072
# 33/33 [==============================] - 49s 1s/step - loss: 0.7310 - auc: 0.9030 - accuracy: 0.8413 - precision: 0.7109 - recall: 0.6157 - f1_score: 0.6548 - val_loss: 1.0111 - val_auc: 0.8361 - val_accuracy: 0.7820 - val_precision: 0.5730 - val_recall: 0.5024 - val_f1_score: 0.5352
# Epoch 20/20
# 33/33 [==============================] - ETA: 0s - loss: 0.7201 - auc: 0.9057 - accuracy: 0.8432 - precision: 0.7140 - recall: 0.6215 - f1_score: 0.6645
# Epoch 00020: val_auc did not improve from 0.84072
# 33/33 [==============================] - 50s 2s/step - loss: 0.7201 - auc: 0.9057 - accuracy: 0.8432 - precision: 0.7140 - recall: 0.6215 - f1_score: 0.6645 - val_loss: 0.9683 - val_auc: 0.8377 - val_accuracy: 0.7803 - val_precision: 0.5705 - val_recall: 0.4907 - val_f1_score: 0.5273

# %%
# Summarize history for loss

plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left', bbox_to_anchor=(1,1))
plt.show()

# %%
# Summarize history for loss

plt.plot(model_history.history['auc'])
plt.plot(model_history.history['val_auc'])
plt.title('Model AUC')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left', bbox_to_anchor=(1,1))
plt.show()

# %%
model.evaluate(test_dataset)
# Out:
# 40/40 [==============================] - 3s 70ms/step - loss: 0.8188 - auc: 0.8899 - accuracy: 0.8297 - precision: 0.6753 - recall: 0.6145 - f1_score: 0.6427
# [0.8187960982322693,
#  0.8898926377296448,
#  0.8297498226165771,
#  0.6752577424049377,
#  0.6145426034927368,
#  0.6426787376403809]

# %%
def predict_prob(number):
    return [number[0],1-number[0]]

# %%
# Test Case 1: Non-Dementia

dic = test_dataset.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('/kaggle/input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/test/NonDemented/26 (100).jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)

classes = np.argmax(model.predict(img),axis=1)

probability = round(np.max(model.predict(img)*100),2)


print(probability, '% chances are there that the image is', classes)
# Out:
# 78.62 % chances are there that the image is [2]

# %%
# Test Case 2: Mild-Dementia

dic = test_dataset.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('/kaggle/input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/test/MildDemented/26 (27).jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)

classes = np.argmax(model.predict(img),axis=1)

probability = round(np.max(model.predict(img)*100),2)


print(probability, '% chances are there that the image is', classes)
# Out:
# 47.78 % chances are there that the image is [0]

# %%
# Test Case 3: Moderate-Dementia

dic = test_dataset.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('/kaggle/input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/test/ModerateDemented/27 (2).jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)

classes = np.argmax(model.predict(img),axis=1)

probability = round(np.max(model.predict(img)*100),2)


print(probability, '% chances are there that the image is', classes)
# Out:
# 75.54 % chances are there that the image is [1]

# %%
# Test Case4 : Moderate-Dementia

dic = test_dataset.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('/kaggle/input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/test/VeryMildDemented/26 (52).jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)

classes = np.argmax(model.predict(img),axis=1)

probability = round(np.max(model.predict(img)*100),2)


print(probability, '% chances are there that the image is', classes)
# Out:
# 80.06 % chances are there that the image is [3]
