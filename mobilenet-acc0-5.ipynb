# %% [markdown]
# ### IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import skimage.io
import os 
import tqdm
import glob
import tensorflow 

from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

from skimage.io import imread, imshow
from skimage.transform import resize
#from skimage.color import grey2rgb

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.utils import to_categorical
from keras import optimizers

from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K

#import tensorflow_addons as tfa
#from tensorflow.keras.metrics import Metric
#from tensorflow_addons.utils.types import AcceptableDTypes, FloatTensorLike
from typeguard import typechecked
from typing import Optional
import tensorflow 

from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from skimage.io import imread, imshow
from skimage.transform import resize
#from skimage.color import grey2rgb

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.densenet import DenseNet169
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import keras.backend as K

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   validation_split = 0.2,
                                  
        rotation_range=5,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
        #zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='nearest')

valid_datagen = ImageDataGenerator(rescale = 1./255,
                                  validation_split = 0.2)

test_datagen  = ImageDataGenerator(rescale = 1./255
                                  )

# %%
#train_dataset = tf.keras.preprocessing.image_dataset_from_directory('../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/train',
#                                                                        validation_split=0.2,
#                                                                        subset="training",
#                                                                        shuffle=False,
#                                                                        image_size=(224,224),
#                                                                        batch_size=32,
#                                                                        )

train_dataset  = train_datagen.flow_from_directory(directory = '../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/train',
                                                   target_size = (224,224),
                                                   class_mode = 'categorical',
                                                   subset = 'training',
                                                   batch_size = 128)
# Out:
# Found 4098 images belonging to 4 classes.

# %%
#valid_dataset = tf.keras.preprocessing.image_dataset_from_directory('../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/train',
#                                                                        validation_split=0.2,
#                                                                        subset="validation",
#                                                                        shuffle=False,
#                                                                        image_size=(224,224),
#                                                                        batch_size=32,
#                                                                        )
valid_dataset = valid_datagen.flow_from_directory(directory = '../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/train',
                                                  target_size = (224,224),
                                                  class_mode = 'categorical',
                                                  subset = 'validation',
                                                  batch_size = 128)
# Out:
# Found 1023 images belonging to 4 classes.

# %% [markdown]
# ## feature preprocessing and label encoding.

# %% [markdown]
# ### MODEL BUILDING

# %%
base_model = tf.keras.applications.MobileNetV2(input_shape=(224,224,3), 
                   include_top=False,
                   weights="imagenet")
# Out:
# 2023-01-08 12:42:56.862202: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# 9420800/9406464 [==============================] - 0s 0us/step

# %%
# Freezing Layers

for layer in base_model.layers:
    layer.trainable=False

# %%
# Building Model

model=Sequential()
model.add(base_model)
model.add(Dropout(0.5))
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(4,activation='softmax'))

# %%
# Model Summary

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_224 (Functi (None, 7, 7, 1280)        2257984
# _________________________________________________________________
# dropout (Dropout)            (None, 7, 7, 1280)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 62720)             0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 62720)             250880
# _________________________________________________________________
# dense (Dense)                (None, 32)                2007072
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32)                128
# _________________________________________________________________
# activation (Activation)      (None, 32)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                1056
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32)                128
# _________________________________________________________________
# activation_1 (Activation)    (None, 32)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                1056
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32)                128
# _________________________________________________________________
# activation_2 (Activation)    (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 132
# =================================================================
# Total params: 4,518,564
# Trainable params: 2,134,948
# Non-trainable params: 2,383,616
# _________________________________________________________________

# %%
def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
OPT    = tensorflow.keras.optimizers.Adam(lr=0.001)
METRICS = [
      tensorflow.keras.metrics.AUC(name = 'auc'),
      tensorflow.keras.metrics.CategoricalAccuracy(name='accuracy'),
      tensorflow.keras.metrics.Precision(name='precision'),
      tensorflow.keras.metrics.Recall(name='recall'),  
        f1_score,
          ]
model.compile(loss='categorical_crossentropy',
              metrics=METRICS,
              optimizer=OPT)
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
# Defining Callbacks
filepath = '/kaggle/working/best_weights_mos.hdf5'

earlystopping = EarlyStopping(monitor = 'val_auc', 
                              mode = 'max' , 
                              patience = 15,
                              verbose = 1)

checkpoint    = ModelCheckpoint(filepath, 
                                monitor = 'val_auc', 
                                mode='max', 
                                save_best_only=True, 
                                verbose = 1)


callback_list = [earlystopping, checkpoint]

# %%
model_history=model.fit(train_dataset,
                        validation_data=valid_dataset,
                        epochs = 100,
                        callbacks = callback_list,
                        verbose = 1)
# Out:
# Epoch 1/100
# 33/33 [==============================] - 118s 4s/step - loss: 1.8473 - auc: 0.4073 - accuracy: 0.1735 - precision: 0.1601 - recall: 0.0556 - f1_score: 0.0804 - val_loss: 1.4330 - val_auc: 0.5635 - val_accuracy: 0.2835 - val_precision: 0.1336 - val_recall: 0.0303 - val_f1_score: 0.0492
#
# Epoch 00001: val_auc improved from -inf to 0.56346, saving model to /kaggle/working/best_weights_mos.hdf5
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/100
# 33/33 [==============================] - 103s 3s/step - loss: 1.3876 - auc: 0.6071 - accuracy: 0.3404 - precision: 0.3571 - recall: 0.0610 - f1_score: 0.1001 - val_loss: 1.1787 - val_auc: 0.7545 - val_accuracy: 0.4633 - val_precision: 0.6067 - val_recall: 0.0528 - val_f1_score: 0.0969
#
# Epoch 00002: val_auc improved from 0.56346 to 0.75451, saving model to /kaggle/working/best_weights_mos.hdf5
# Epoch 3/100
# 33/33 [==============================] - 104s 3s/step - loss: 1.2024 - auc: 0.7303 - accuracy: 0.4568 - precision: 0.5537 - recall: 0.1396 - f1_score: 0.2149 - val_loss: 1.0793 - val_auc: 0.8032 - val_accuracy: 0.5239 - val_precision: 0.6198 - val_recall: 0.3060 - val_f1_score: 0.4086
#
# Epoch 00003: val_auc improved from 0.75451 to 0.80320, saving model to /kaggle/working/best_weights_mos.hdf5
# Epoch 4/100
# 33/33 [==============================] - 103s 3s/step - loss: 1.1165 - auc: 0.7730 - accuracy: 0.4927 - precision: 0.5952 - recall: 0.2289 - f1_score: 0.3198 - val_loss: 1.0624 - val_auc: 0.8048 - val_accuracy: 0.5269 - val_precision: 0.5963 - val_recall: 0.3480 - val_f1_score: 0.4390
#
# Epoch 00004: val_auc improved from 0.80320 to 0.80476, saving model to /kaggle/working/best_weights_mos.hdf5
# Epoch 5/100
# 33/33 [==============================] - 104s 3s/step - loss: 1.0616 - auc: 0.7956 - accuracy: 0.5098 - precision: 0.6045 - recall: 0.2667 - f1_score: 0.3582 - val_loss: 1.0695 - val_auc: 0.7973 - val_accuracy: 0.5367 - val_precision: 0.5929 - val_recall: 0.3431 - val_f1_score: 0.4338
#
# Epoch 00005: val_auc did not improve from 0.80476
# Epoch 6/100
# 33/33 [==============================] - 103s 3s/step - loss: 1.0252 - auc: 0.8087 - accuracy: 0.5312 - precision: 0.6185 - recall: 0.3177 - f1_score: 0.4364 - val_loss: 1.0724 - val_auc: 0.7927 - val_accuracy: 0.5327 - val_precision: 0.5719 - val_recall: 0.3421 - val_f1_score: 0.4270
#
# Epoch 00006: val_auc did not improve from 0.80476
# Epoch 7/100
# 33/33 [==============================] - 103s 3s/step - loss: 1.0228 - auc: 0.8068 - accuracy: 0.5220 - precision: 0.6157 - recall: 0.3448 - f1_score: 0.4286 - val_loss: 1.0540 - val_auc: 0.7992 - val_accuracy: 0.5455 - val_precision: 0.5891 - val_recall: 0.3587 - val_f1_score: 0.4459
#
# Epoch 00007: val_auc did not improve from 0.80476
# Epoch 8/100
# 33/33 [==============================] - 103s 3s/step - loss: 1.0012 - auc: 0.8140 - accuracy: 0.5300 - precision: 0.6026 - recall: 0.3455 - f1_score: 0.4260 - val_loss: 1.0414 - val_auc: 0.8062 - val_accuracy: 0.5249 - val_precision: 0.6084 - val_recall: 0.3978 - val_f1_score: 0.4803
#
# Epoch 00008: val_auc improved from 0.80476 to 0.80618, saving model to /kaggle/working/best_weights_mos.hdf5
# Epoch 9/100
# 33/33 [==============================] - 102s 3s/step - loss: 0.9735 - auc: 0.8243 - accuracy: 0.5439 - precision: 0.6426 - recall: 0.3558 - f1_score: 0.4639 - val_loss: 1.0361 - val_auc: 0.8083 - val_accuracy: 0.5220 - val_precision: 0.6195 - val_recall: 0.3978 - val_f1_score: 0.4844
#
# Epoch 00009: val_auc improved from 0.80618 to 0.80827, saving model to /kaggle/working/best_weights_mos.hdf5
# Epoch 10/100
# 33/33 [==============================] - 103s 3s/step - loss: 0.9702 - auc: 0.8254 - accuracy: 0.5476 - precision: 0.6417 - recall: 0.3658 - f1_score: 0.4519 - val_loss: 1.0459 - val_auc: 0.8119 - val_accuracy: 0.5132 - val_precision: 0.5882 - val_recall: 0.4174 - val_f1_score: 0.4880
#
# Epoch 00010: val_auc improved from 0.80827 to 0.81190, saving model to /kaggle/working/best_weights_mos.hdf5
# Epoch 11/100
# 33/33 [==============================] - 103s 3s/step - loss: 0.9740 - auc: 0.8223 - accuracy: 0.5412 - precision: 0.6347 - recall: 0.3629 - f1_score: 0.4621 - val_loss: 1.0082 - val_auc: 0.8092 - val_accuracy: 0.5239 - val_precision: 0.6279 - val_recall: 0.3695 - val_f1_score: 0.4653
#
# Epoch 00011: val_auc did not improve from 0.81190
# Epoch 12/100
# 33/33 [==============================] - 103s 3s/step - loss: 0.9584 - auc: 0.8292 - accuracy: 0.5512 - precision: 0.6350 - recall: 0.3816 - f1_score: 0.4770 - val_loss: 1.0140 - val_auc: 0.8144 - val_accuracy: 0.5142 - val_precision: 0.6248 - val_recall: 0.3939 - val_f1_score: 0.4825
#
# Epoch 00012: val_auc improved from 0.81190 to 0.81442, saving model to /kaggle/working/best_weights_mos.hdf5
# Epoch 13/100
# 33/33 [==============================] - 104s 3s/step - loss: 0.9554 - auc: 0.8284 - accuracy: 0.5405 - precision: 0.6315 - recall: 0.3626 - f1_score: 0.4664 - val_loss: 1.0161 - val_auc: 0.8104 - val_accuracy: 0.5200 - val_precision: 0.6186 - val_recall: 0.3773 - val_f1_score: 0.4676
#
# Epoch 00013: val_auc did not improve from 0.81442
# Epoch 14/100
# 33/33 [==============================] - 104s 3s/step - loss: 0.9435 - auc: 0.8326 - accuracy: 0.5486 - precision: 0.6413 - recall: 0.3848 - f1_score: 0.4862 - val_loss: 1.0380 - val_auc: 0.8065 - val_accuracy: 0.5298 - val_precision: 0.5896 - val_recall: 0.3891 - val_f1_score: 0.4679
#
# Epoch 00014: val_auc did not improve from 0.81442
# Epoch 15/100
# 33/33 [==============================] - 103s 3s/step - loss: 0.9473 - auc: 0.8305 - accuracy: 0.5432 - precision: 0.6378 - recall: 0.3829 - f1_score: 0.4790 - val_loss: 1.0323 - val_auc: 0.8055 - val_accuracy: 0.5122 - val_precision: 0.6171 - val_recall: 0.3812 - val_f1_score: 0.4713
#
# Epoch 00015: val_auc did not improve from 0.81442
# Epoch 16/100
# 33/33 [==============================] - 103s 3s/step - loss: 0.9318 - auc: 0.8363 - accuracy: 0.5571 - precision: 0.6476 - recall: 0.3812 - f1_score: 0.4656 - val_loss: 1.0140 - val_auc: 0.8115 - val_accuracy: 0.5161 - val_precision: 0.5983 - val_recall: 0.4135 - val_f1_score: 0.4895
#
# Epoch 00016: val_auc did not improve from 0.81442
# Epoch 17/100
# 33/33 [==============================] - 106s 3s/step - loss: 0.9294 - auc: 0.8378 - accuracy: 0.5578 - precision: 0.6642 - recall: 0.3890 - f1_score: 0.4907 - val_loss: 1.0487 - val_auc: 0.8087 - val_accuracy: 0.5132 - val_precision: 0.5659 - val_recall: 0.4282 - val_f1_score: 0.4879
#
# Epoch 00017: val_auc did not improve from 0.81442
# Epoch 18/100
# 33/33 [==============================] - 104s 3s/step - loss: 0.9203 - auc: 0.8404 - accuracy: 0.5642 - precision: 0.6467 - recall: 0.3953 - f1_score: 0.4955 - val_loss: 1.0405 - val_auc: 0.8056 - val_accuracy: 0.5083 - val_precision: 0.5695 - val_recall: 0.4203 - val_f1_score: 0.4837
#
# Epoch 00018: val_auc did not improve from 0.81442
# Epoch 19/100
# 33/33 [==============================] - 103s 3s/step - loss: 0.9199 - auc: 0.8424 - accuracy: 0.5686 - precision: 0.6514 - recall: 0.4241 - f1_score: 0.5280 - val_loss: 1.0334 - val_auc: 0.8071 - val_accuracy: 0.5249 - val_precision: 0.5587 - val_recall: 0.4184 - val_f1_score: 0.4784
#
# Epoch 00019: val_auc did not improve from 0.81442
# Epoch 20/100
# 33/33 [==============================] - 103s 3s/step - loss: 0.9225 - auc: 0.8413 - accuracy: 0.5730 - precision: 0.6467 - recall: 0.4158 - f1_score: 0.5055 - val_loss: 1.0317 - val_auc: 0.8064 - val_accuracy: 0.5269 - val_precision: 0.5638 - val_recall: 0.4106 - val_f1_score: 0.4747
#
# Epoch 00020: val_auc did not improve from 0.81442
# Epoch 21/100
# 33/33 [==============================] - 104s 3s/step - loss: 0.9007 - auc: 0.8485 - accuracy: 0.5761 - precision: 0.6728 - recall: 0.4114 - f1_score: 0.5149 - val_loss: 1.0312 - val_auc: 0.8021 - val_accuracy: 0.5191 - val_precision: 0.5370 - val_recall: 0.3969 - val_f1_score: 0.4557
#
# Epoch 00021: val_auc did not improve from 0.81442
# Epoch 22/100
# 33/33 [==============================] - 102s 3s/step - loss: 0.8974 - auc: 0.8494 - accuracy: 0.5869 - precision: 0.6721 - recall: 0.4202 - f1_score: 0.5013 - val_loss: 1.0468 - val_auc: 0.7999 - val_accuracy: 0.5103 - val_precision: 0.5236 - val_recall: 0.3900 - val_f1_score: 0.4463
#
# Epoch 00022: val_auc did not improve from 0.81442
# Epoch 23/100
# 33/33 [==============================] - 103s 3s/step - loss: 0.9094 - auc: 0.8457 - accuracy: 0.5678 - precision: 0.6604 - recall: 0.4100 - f1_score: 0.5102 - val_loss: 1.0197 - val_auc: 0.8087 - val_accuracy: 0.5269 - val_precision: 0.5451 - val_recall: 0.4194 - val_f1_score: 0.4742
#
# Epoch 00023: val_auc did not improve from 0.81442
# Epoch 24/100
# 33/33 [==============================] - 103s 3s/step - loss: 0.9052 - auc: 0.8463 - accuracy: 0.5730 - precision: 0.6752 - recall: 0.4063 - f1_score: 0.5068 - val_loss: 1.0279 - val_auc: 0.8158 - val_accuracy: 0.5259 - val_precision: 0.5425 - val_recall: 0.4428 - val_f1_score: 0.4876
#
# Epoch 00024: val_auc improved from 0.81442 to 0.81578, saving model to /kaggle/working/best_weights_mos.hdf5
# Epoch 25/100
# 33/33 [==============================] - 105s 3s/step - loss: 0.8947 - auc: 0.8506 - accuracy: 0.5791 - precision: 0.6678 - recall: 0.4234 - f1_score: 0.5025 - val_loss: 1.0059 - val_auc: 0.8117 - val_accuracy: 0.5191 - val_precision: 0.5708 - val_recall: 0.3939 - val_f1_score: 0.4661
#
# Epoch 00025: val_auc did not improve from 0.81578
# Epoch 26/100
# 33/33 [==============================] - 103s 3s/step - loss: 0.8978 - auc: 0.8512 - accuracy: 0.5898 - precision: 0.6774 - recall: 0.4141 - f1_score: 0.5282 - val_loss: 1.0200 - val_auc: 0.8109 - val_accuracy: 0.5269 - val_precision: 0.5700 - val_recall: 0.4018 - val_f1_score: 0.4713
#
# Epoch 00026: val_auc did not improve from 0.81578
# Epoch 27/100
# 33/33 [==============================] - 103s 3s/step - loss: 0.8800 - auc: 0.8561 - accuracy: 0.5891 - precision: 0.6858 - recall: 0.4278 - f1_score: 0.5109 - val_loss: 1.0175 - val_auc: 0.8157 - val_accuracy: 0.5376 - val_precision: 0.5583 - val_recall: 0.4399 - val_f1_score: 0.4920
#
# Epoch 00027: val_auc did not improve from 0.81578
# Epoch 28/100
# 33/33 [==============================] - 104s 3s/step - loss: 0.8782 - auc: 0.8558 - accuracy: 0.5857 - precision: 0.6853 - recall: 0.4251 - f1_score: 0.5287 - val_loss: 1.0280 - val_auc: 0.8124 - val_accuracy: 0.5220 - val_precision: 0.5616 - val_recall: 0.4233 - val_f1_score: 0.4826
#
# Epoch 00028: val_auc did not improve from 0.81578
# Epoch 29/100
# 33/33 [==============================] - 103s 3s/step - loss: 0.8759 - auc: 0.8577 - accuracy: 0.5935 - precision: 0.6813 - recall: 0.4388 - f1_score: 0.5176 - val_loss: 1.0482 - val_auc: 0.8150 - val_accuracy: 0.5249 - val_precision: 0.5537 - val_recall: 0.4438 - val_f1_score: 0.4920
#
# Epoch 00029: val_auc did not improve from 0.81578
# Epoch 30/100
# 33/33 [==============================] - 104s 3s/step - loss: 0.8765 - auc: 0.8578 - accuracy: 0.5896 - precision: 0.6733 - recall: 0.4571 - f1_score: 0.5578 - val_loss: 1.0261 - val_auc: 0.8130 - val_accuracy: 0.5220 - val_precision: 0.5504 - val_recall: 0.4213 - val_f1_score: 0.4766
#
# Epoch 00030: val_auc did not improve from 0.81578
# Epoch 31/100
# 33/33 [==============================] - 103s 3s/step - loss: 0.8691 - auc: 0.8583 - accuracy: 0.5854 - precision: 0.6669 - recall: 0.4407 - f1_score: 0.5345 - val_loss: 1.0381 - val_auc: 0.8155 - val_accuracy: 0.5142 - val_precision: 0.5579 - val_recall: 0.4330 - val_f1_score: 0.4874
#
# Epoch 00031: val_auc did not improve from 0.81578
# Epoch 32/100
# 33/33 [==============================] - 105s 3s/step - loss: 0.8719 - auc: 0.8598 - accuracy: 0.6003 - precision: 0.6915 - recall: 0.4524 - f1_score: 0.5302 - val_loss: 1.0192 - val_auc: 0.8185 - val_accuracy: 0.5161 - val_precision: 0.5671 - val_recall: 0.4379 - val_f1_score: 0.4940
#
# Epoch 00032: val_auc improved from 0.81578 to 0.81848, saving model to /kaggle/working/best_weights_mos.hdf5
# Epoch 33/100
# 33/33 [==============================] - 104s 3s/step - loss: 0.8644 - auc: 0.8616 - accuracy: 0.5986 - precision: 0.6776 - recall: 0.4544 - f1_score: 0.5476 - val_loss: 1.0044 - val_auc: 0.8198 - val_accuracy: 0.5220 - val_precision: 0.5667 - val_recall: 0.4321 - val_f1_score: 0.4898
#
# Epoch 00033: val_auc improved from 0.81848 to 0.81985, saving model to /kaggle/working/best_weights_mos.hdf5
# Epoch 34/100
# 33/33 [==============================] - 104s 3s/step - loss: 0.8668 - auc: 0.8602 - accuracy: 0.5964 - precision: 0.6735 - recall: 0.4519 - f1_score: 0.5544 - val_loss: 1.0370 - val_auc: 0.8136 - val_accuracy: 0.5142 - val_precision: 0.5378 - val_recall: 0.4242 - val_f1_score: 0.4740
#
# Epoch 00034: val_auc did not improve from 0.81985
# Epoch 35/100
# 33/33 [==============================] - 104s 3s/step - loss: 0.8657 - auc: 0.8606 - accuracy: 0.5922 - precision: 0.6800 - recall: 0.4553 - f1_score: 0.5488 - val_loss: 1.0590 - val_auc: 0.8128 - val_accuracy: 0.5034 - val_precision: 0.5504 - val_recall: 0.4213 - val_f1_score: 0.4771
#
# Epoch 00035: val_auc did not improve from 0.81985
# Epoch 36/100
# 33/33 [==============================] - 103s 3s/step - loss: 0.8530 - auc: 0.8645 - accuracy: 0.6015 - precision: 0.6818 - recall: 0.4607 - f1_score: 0.5482 - val_loss: 1.0617 - val_auc: 0.8122 - val_accuracy: 0.5015 - val_precision: 0.5642 - val_recall: 0.4125 - val_f1_score: 0.4765
#
# Epoch 00036: val_auc did not improve from 0.81985
# Epoch 37/100
# 33/33 [==============================] - 103s 3s/step - loss: 0.8532 - auc: 0.8649 - accuracy: 0.6022 - precision: 0.6826 - recall: 0.4661 - f1_score: 0.5374 - val_loss: 1.0708 - val_auc: 0.8129 - val_accuracy: 0.5054 - val_precision: 0.5618 - val_recall: 0.4223 - val_f1_score: 0.4821
#
# Epoch 00037: val_auc did not improve from 0.81985
# Epoch 38/100
# 33/33 [==============================] - 104s 3s/step - loss: 0.8634 - auc: 0.8621 - accuracy: 0.5986 - precision: 0.6804 - recall: 0.4619 - f1_score: 0.5336 - val_loss: 1.0520 - val_auc: 0.8119 - val_accuracy: 0.5034 - val_precision: 0.5691 - val_recall: 0.4106 - val_f1_score: 0.4763
#
# Epoch 00038: val_auc did not improve from 0.81985
# Epoch 39/100
# 33/33 [==============================] - 103s 3s/step - loss: 0.8667 - auc: 0.8606 - accuracy: 0.5966 - precision: 0.6802 - recall: 0.4624 - f1_score: 0.5490 - val_loss: 1.0377 - val_auc: 0.8109 - val_accuracy: 0.4927 - val_precision: 0.5762 - val_recall: 0.4066 - val_f1_score: 0.4766
#
# Epoch 00039: val_auc did not improve from 0.81985
# Epoch 40/100
# 33/33 [==============================] - 102s 3s/step - loss: 0.8488 - auc: 0.8652 - accuracy: 0.5959 - precision: 0.6841 - recall: 0.4588 - f1_score: 0.5526 - val_loss: 1.0419 - val_auc: 0.8102 - val_accuracy: 0.4868 - val_precision: 0.5529 - val_recall: 0.4037 - val_f1_score: 0.4664
#
# Epoch 00040: val_auc did not improve from 0.81985
# Epoch 41/100
# 33/33 [==============================] - 102s 3s/step - loss: 0.8460 - auc: 0.8683 - accuracy: 0.6122 - precision: 0.6851 - recall: 0.4741 - f1_score: 0.5434 - val_loss: 1.0256 - val_auc: 0.8141 - val_accuracy: 0.5034 - val_precision: 0.5410 - val_recall: 0.4321 - val_f1_score: 0.4804
#
# Epoch 00041: val_auc did not improve from 0.81985
# Epoch 42/100
# 33/33 [==============================] - 103s 3s/step - loss: 0.8614 - auc: 0.8640 - accuracy: 0.6088 - precision: 0.6886 - recall: 0.4758 - f1_score: 0.5609 - val_loss: 1.0113 - val_auc: 0.8138 - val_accuracy: 0.4956 - val_precision: 0.5573 - val_recall: 0.4135 - val_f1_score: 0.4750
#
# Epoch 00042: val_auc did not improve from 0.81985
# Epoch 43/100
# 33/33 [==============================] - 103s 3s/step - loss: 0.8473 - auc: 0.8688 - accuracy: 0.6157 - precision: 0.6912 - recall: 0.4644 - f1_score: 0.5587 - val_loss: 1.0270 - val_auc: 0.8151 - val_accuracy: 0.4985 - val_precision: 0.5503 - val_recall: 0.4282 - val_f1_score: 0.4819
#
# Epoch 00043: val_auc did not improve from 0.81985
# Epoch 44/100
# 33/33 [==============================] - 103s 3s/step - loss: 0.8477 - auc: 0.8675 - accuracy: 0.6093 - precision: 0.6863 - recall: 0.4778 - f1_score: 0.5462 - val_loss: 1.0117 - val_auc: 0.8142 - val_accuracy: 0.4927 - val_precision: 0.5507 - val_recall: 0.4194 - val_f1_score: 0.4758
#
# Epoch 00044: val_auc did not improve from 0.81985
# Epoch 45/100
# 33/33 [==============================] - 103s 3s/step - loss: 0.8567 - auc: 0.8645 - accuracy: 0.6091 - precision: 0.6794 - recall: 0.4653 - f1_score: 0.5507 - val_loss: 1.0231 - val_auc: 0.8176 - val_accuracy: 0.5054 - val_precision: 0.5648 - val_recall: 0.4301 - val_f1_score: 0.4878
#
# Epoch 00045: val_auc did not improve from 0.81985
# Epoch 46/100
# 33/33 [==============================] - 102s 3s/step - loss: 0.8349 - auc: 0.8719 - accuracy: 0.6210 - precision: 0.6944 - recall: 0.4785 - f1_score: 0.5646 - val_loss: 1.0028 - val_auc: 0.8104 - val_accuracy: 0.4848 - val_precision: 0.5812 - val_recall: 0.3920 - val_f1_score: 0.4680
#
# Epoch 00046: val_auc did not improve from 0.81985
# Epoch 47/100
# 33/33 [==============================] - 102s 3s/step - loss: 0.8386 - auc: 0.8710 - accuracy: 0.6223 - precision: 0.6895 - recall: 0.4822 - f1_score: 0.5702 - val_loss: 1.0057 - val_auc: 0.8175 - val_accuracy: 0.5093 - val_precision: 0.5632 - val_recall: 0.4223 - val_f1_score: 0.4817
#
# Epoch 00047: val_auc did not improve from 0.81985
# Epoch 48/100
# 33/33 [==============================] - 102s 3s/step - loss: 0.8327 - auc: 0.8723 - accuracy: 0.6184 - precision: 0.6941 - recall: 0.4912 - f1_score: 0.5726 - val_loss: 1.0056 - val_auc: 0.8168 - val_accuracy: 0.4956 - val_precision: 0.5638 - val_recall: 0.4233 - val_f1_score: 0.4834
#
# Epoch 00048: val_auc did not improve from 0.81985
# Epoch 00048: early stopping

# %%
from tensorflow.keras.utils import to_categorical, plot_model
#plot_model(model, to_file='NN-mnist.png', show_shapes=True)

# %%
#model.load_weights("/kaggle/input/zahaimar-22/zahaimar_v2.h5")

# %%
#model.compile(optimizer='rmsprop', loss='categorical_crossentropy',metrics=METRICS)

# %%
#test_dataset = tf.keras.preprocessing.image_dataset_from_directory("../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/test",
##                                                            shuffle=False,
#                                                            image_size=(224,224),
#                                                            batch_size=32,
#)

test_dataset = test_datagen.flow_from_directory(directory = '../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/test',
                                                  target_size = (224,224),
                                                  class_mode = 'categorical'
                                                  )
# Out:
# Found 1279 images belonging to 4 classes.

# %%
#%% PLOTTING RESULTS (Train vs Validation FOLDER 1)

def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1,val_f1):
    
    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    
    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])
    
    ax5.plot(range(1, len(f1) + 1), f1)
    ax5.plot(range(1, len(val_f1) + 1), val_f1)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.legend(['training', 'validation'])


    plt.show()
    

Train_Val_Plot(model_history.history['accuracy'],model_history.history['val_accuracy'],
               model_history.history['loss'],model_history.history['val_loss'],
               model_history.history['auc'],model_history.history['val_auc'],
               model_history.history['precision'],model_history.history['val_precision'],
               model_history.history['f1_score'],model_history.history['val_f1_score']
              )

# %%
scores = model.evaluate(test_dataset)
# Out:
# 40/40 [==============================] - 16s 396ms/step - loss: 1.0283 - auc: 0.8421 - accuracy: 0.5739 - precision: 0.5943 - recall: 0.5199 - f1_score: 0.5540

# %%
print("Accuracy = ", scores[1])
print("Precision = ", scores[2])
print("Recall = ", scores[3])
print("AUC = ", scores[4])
print("F1_score = ", scores[5])
# Out:
# Accuracy =  0.8421139717102051
# Precision =  0.5738858580589294
# Recall =  0.5942806005477905
# AUC =  0.5199374556541443
# F1_score =  0.553989052772522

# %% [markdown]
# # Test on the DataSet

# %%
# Test Case 1: Non-Dementia

dic = test_dataset.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('/kaggle/input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/test/VeryMildDemented/26 (49).jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)

classes = np.argmax(model.predict(img),axis=1)

probability = round(np.max(model.predict(img)*100),2)


print(probability, '% chances are there that the image is', classes)
# Out:
# 56.14 % chances are there that the image is [2]

# %%
# Test Case 2: 

dic = test_dataset.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('/kaggle/input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/test/NonDemented/26 (100).jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)

classes = np.argmax(model.predict(img),axis=1)

probability = round(np.max(model.predict(img)*100),2)


print(probability, '% chances are there that the image is', classes)
# Out:
# 87.5 % chances are there that the image is [2]

# %% [markdown]
# # Confusion Matrix

# %%
model.save('/kaggle/working/zahaimar_v2_lolllly.h5')
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %%
true_classes = test_dataset.classes
class_indices = test_dataset.class_indices
class_indices = dict((v,k) for k,v in class_indices.items())

preds = model.predict(test_dataset)
pred_classes = np.argmax(preds, axis=1)

# %%
print(train_dataset.class_indices.keys())
# Out:
# dict_keys(['MildDemented', 'ModerateDemented', 'NonDemented', 'VeryMildDemented'])

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Get the names of the ten classes
class_names = test_dataset.class_indices.keys()

def plot_heatmap(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    sns.heatmap(
        cm, 
        annot=True, 
        square=True, 
        fmt='d', 
        cmap=plt.cm.Blues,
        cbar=False,
    )

plt.figure()
plot_heatmap(true_classes, pred_classes)    

plt.show()

# %% [markdown]
# #
